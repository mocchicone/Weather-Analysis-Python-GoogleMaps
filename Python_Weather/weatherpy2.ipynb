# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)

cities
# Out:
# ['castro',
#  'bambous virieux',
#  'port elizabeth',
#  'severo-kurilsk',
#  'rikitea',
#  'barentsburg',
#  'palabuhanratu',
#  'vaini',
#  'itoman',
#  'dikson',
#  'sentyabrskiy',
#  'tiksi',
#  'mataura',
#  'punta arenas',
#  'tiznit',
#  'busselton',
#  'boditi',
#  'carnarvon',
#  'lisakovsk',
#  'peniche',
#  'albany',
#  'tabiauea',
#  'bambanglipuro',
#  'klaksvik',
#  'sucre',
#  'ambatondrazaka',
#  'thunder bay',
#  'mahebourg',
#  'lebu',
#  'bredasdorp',
#  'puerto ayora',
#  'clyde river',
#  'qaanaaq',
#  'marzuq',
#  'ushuaia',
#  'el real de santa maria',
#  'saleaula',
#  'kapaa',
#  'charters towers',
#  'umzimvubu',
#  'grand river south east',
#  'codrington',
#  'nizhneyansk',
#  'cairns',
#  'bantou',
#  'touros',
#  'kodar',
#  'coquimbo',
#  'verkhnevilyuysk',
#  'upernavik',
#  'lasa',
#  'jamestown',
#  'ostrovnoy',
#  'luderitz',
#  'atuona',
#  'komsomolskiy',
#  'cabo san lucas',
#  'hobart',
#  'tasiilaq',
#  'kruisfontein',
#  'malayal',
#  'bluff',
#  'teya',
#  'kaitangata',
#  'vila velha',
#  'norman wells',
#  'tabou',
#  'san juan del sur',
#  'cogealac',
#  'raudeberg',
#  'mikuni',
#  'puerto baquerizo moreno',
#  'pevek',
#  'kodiak',
#  'cidreira',
#  'ponta do sol',
#  'butaritari',
#  'amderma',
#  'mount gambier',
#  'attawapiskat',
#  'bryan',
#  'avarua',
#  'cacador',
#  'kosh-agach',
#  'karkaralinsk',
#  'mareeba',
#  'waingapu',
#  'saskylakh',
#  'laguna',
#  'mar del plata',
#  'pozo colorado',
#  'provideniya',
#  'yellowknife',
#  'roma',
#  'ilulissat',
#  'taganak',
#  'hithadhoo',
#  'onalaska',
#  'grindavik',
#  'salalah',
#  'ruatoria',
#  'yeppoon',
#  'chokurdakh',
#  'georgetown',
#  'plouzane',
#  'chuy',
#  'regente feijo',
#  'tsihombe',
#  'bentiu',
#  'young',
#  'tumannyy',
#  'sitka',
#  'los llanos de aridane',
#  'port hardy',
#  'thompson',
#  'mustasaari',
#  'kirakira',
#  'gurgan',
#  'nikolskoye',
#  'ribeira grande',
#  'arraial do cabo',
#  'brigantine',
#  'leghorn',
#  'shelburne',
#  'barrow',
#  'pangnirtung',
#  'sisimiut',
#  'victoria',
#  'hermanus',
#  'taolanaro',
#  'neryungri',
#  'nanortalik',
#  'pacifica',
#  'yulara',
#  'isangel',
#  'hay river',
#  'belushya guba',
#  'lufilufi',
#  'new norfolk',
#  'itaituba',
#  'richards bay',
#  'tornio',
#  'sidi ali',
#  'tautira',
#  'fort nelson',
#  'kuche',
#  'kushiro',
#  'loukhi',
#  'ahipara',
#  'bastrop',
#  'kavaratti',
#  'urengoy',
#  'el sauzal',
#  'arlit',
#  'skjervoy',
#  'kloulklubed',
#  'samarai',
#  'havre-saint-pierre',
#  'faanui',
#  'hilo',
#  'vaitupu',
#  'haines junction',
#  'tuktoyaktuk',
#  'benguela',
#  'ratholo',
#  'sioux lookout',
#  'tazovskiy',
#  'padang',
#  'sampit',
#  'krasnyy yar',
#  'bethel',
#  'kidal',
#  'colac',
#  'jumla',
#  'khatanga',
#  'uray',
#  'neuquen',
#  'cape town',
#  'fortuna',
#  'san quintin',
#  'banihal',
#  'muros',
#  'tiarei',
#  'seymchan',
#  'bakchar',
#  'ucluelet',
#  'nadym',
#  'san carlos de bariloche',
#  'abnub',
#  'namibe',
#  'maloshuyka',
#  'esperance',
#  'muroto',
#  'celestun',
#  'litovko',
#  'boa vista',
#  'avera',
#  'comodoro rivadavia',
#  'ouesso',
#  'yinchuan',
#  'broome',
#  'lompoc',
#  'dharchula',
#  'beian',
#  'belaya gora',
#  'gravdal',
#  'pilar',
#  'kenai',
#  'pimenta bueno',
#  'firovo',
#  'abu samrah',
#  'la reforma',
#  'portland',
#  'saint-augustin',
#  'balfour',
#  'port-cartier',
#  'guerrero negro',
#  'souillac',
#  'leningradskiy',
#  'acarau',
#  'oyem',
#  'gainesville',
#  'hamilton',
#  'gamba',
#  'illoqqortoormiut',
#  'yerbogachen',
#  'kaeo',
#  'rawson',
#  'airai',
#  'omsukchan',
#  'ulladulla',
#  'mirnyy',
#  'gejiu',
#  'kilimatinde',
#  'pokrovsk',
#  'bubaque',
#  'karratha',
#  'samusu',
#  'mana',
#  'nazarovo',
#  'nyrob',
#  'farah',
#  'jalu',
#  'jalingo',
#  'itanhandu',
#  'kalmunai',
#  'araguari',
#  'port alfred',
#  'east london',
#  'saint anthony',
#  'kavieng',
#  'soyo',
#  'samalaeulu',
#  'kanpur',
#  'faya',
#  'barcelona',
#  'batangafo',
#  'bandarbeyla',
#  'talakan',
#  'saint-paul',
#  'kedrovyy',
#  'lemesos',
#  'monrovia',
#  'nioro',
#  'moron',
#  'sokode',
#  'khuzdar',
#  'solsvik',
#  'tarakan',
#  'kamenskoye',
#  'petropavlovsk-kamchatskiy',
#  'ust-kuyga',
#  'urdzhar',
#  'lorengau',
#  'manzil jamil',
#  'iqaluit',
#  'mrirt',
#  'shahr-e kord',
#  'katsuura',
#  'san ramon',
#  'mandiana',
#  'la tuque',
#  'veinticinco de mayo',
#  'hambantota',
#  'riyadh',
#  'vao',
#  'chumikan',
#  'lano',
#  'carballo',
#  'sorland',
#  'mys shmidta',
#  'kropotkin',
#  'vestmannaeyjar',
#  'kaupanger',
#  'prince rupert',
#  'zyryanka',
#  'taua',
#  'coihaique',
#  'phan thiet',
#  'doha',
#  'kiruna',
#  'nishihara',
#  'cascais',
#  'yaan',
#  'maumere',
#  'torbay',
#  'saint-philippe',
#  'george',
#  'kashi',
#  'buritis',
#  'koumac',
#  'chikoy',
#  'saint-joseph',
#  'taman',
#  'viligili',
#  'ust-nera',
#  'bairnsdale',
#  'moose factory',
#  'tucuman',
#  'longhua',
#  'la rioja',
#  'gasa',
#  'montepuez',
#  'kracheh',
#  'khorinsk',
#  'hualmay',
#  'lavrentiya',
#  'bosaso',
#  'banjar',
#  'xuddur',
#  'anshun',
#  'ustka',
#  'darhan',
#  'salinopolis',
#  'salekhard',
#  'beloha',
#  'simao',
#  'boromo',
#  'akropong',
#  'ossora',
#  'carutapera',
#  'tshikapa',
#  'chifeng',
#  'bilibino',
#  'narsaq',
#  'morondava',
#  'san vicente',
#  'bobon',
#  'milledgeville',
#  'baker city',
#  'lagoa',
#  'san patricio',
#  'praia da vitoria',
#  'hun',
#  'vostok',
#  'goderich',
#  'dzhebariki-khaya',
#  'ubinskoye',
#  'cockburn town',
#  'buala',
#  'cuiaba',
#  'kitui',
#  'kibuye',
#  'vila franca do campo',
#  'cap-aux-meules',
#  'marcona',
#  'saint-francois',
#  'pilao arcado',
#  'sumbe',
#  'zirgan',
#  'anloga',
#  'yamada',
#  'shiraz',
#  'galiwinku',
#  'luwuk',
#  'sandpoint',
#  'coxim',
#  'bathsheba',
#  'beyneu',
#  'abrau-dyurso',
#  'tutoia',
#  'formiga',
#  'lima',
#  'wattegama',
#  'kinkala',
#  'corrente',
#  'suez',
#  'macheng',
#  'aksarka',
#  'lasem',
#  'outjo',
#  'egvekinot',
#  'fukuma',
#  'tres palos',
#  'romny',
#  'formosa',
#  'nome',
#  'lolua',
#  'maxixe',
#  'ville-marie',
#  'piracicaba',
#  'tuatapere',
#  'araouane',
#  'kesennuma',
#  'tlapacoyan',
#  'kahului',
#  'cisarua',
#  'khorixas',
#  'broken hill',
#  'dingle',
#  'camacha',
#  'visby',
#  'dwarka',
#  'fairbanks',
#  'fare',
#  'okha',
#  'manado',
#  'trinidad',
#  'cuencame',
#  'stony plain',
#  'gorontalo',
#  'sakakah',
#  'saint-georges',
#  'tumpat',
#  'kupang',
#  'namatanai',
#  'manthani',
#  'itarema',
#  'borba',
#  'saint george',
#  'gemlik',
#  'sambava',
#  'hunza',
#  'amuntai',
#  'machala',
#  'kapuskasing',
#  'sesheke',
#  'erzin',
#  'sao filipe',
#  'loiza',
#  'west plains',
#  'hornepayne',
#  'hays',
#  'bargal',
#  'amahai',
#  'bulgan',
#  'hovd',
#  'dzhusaly',
#  'arona',
#  'tudela',
#  'dalvik',
#  'alofi',
#  'louisbourg',
#  'zwedru',
#  'loandjili',
#  'hagersville',
#  'bacuit',
#  'mitsamiouli',
#  'gaspe',
#  'lamu',
#  'atambua',
#  'burica',
#  'berlevag',
#  'dianopolis',
#  'surt',
#  'pacific grove',
#  'yamethin',
#  'cherskiy',
#  'sonoita',
#  'cap malheureux',
#  'taungdwingyi',
#  'longyearbyen',
#  'da nang',
#  'palmer',
#  'abu kamal',
#  'hollabrunn',
#  'sorvag',
#  'san jeronimo',
#  'chivay',
#  'soloneshnoye',
#  'davila',
#  'fomboni',
#  'geraldton',
#  'tura',
#  'kosa',
#  'fereydun kenar',
#  'hihifo',
#  'aneho',
#  'gushikawa',
#  'san francisco de macoris',
#  'senanga',
#  'darnah',
#  'verkhoyansk',
#  'aklavik',
#  'wamba',
#  'palauig',
#  'matagami',
#  'zelenets',
#  'mozarlandia',
#  'felipe carrillo puerto',
#  'concordia',
#  'maryborough',
#  'buin',
#  'ust-kamchatsk',
#  'solnechnyy',
#  'westport',
#  'marrakesh',
#  'naryan-mar',
#  'ust-kulom',
#  'batagay',
#  'barabinsk',
#  'mamlyutka',
#  'kangar',
#  'jinchang',
#  'yaitepec',
#  'hirara',
#  'abu road',
#  'bengkulu',
#  'saint-pierre',
#  'lata',
#  'inhambane',
#  'luanda',
#  'satitoa',
#  'honningsvag',
#  'sira',
#  'general roca',
#  'petrykiv',
#  'harper',
#  'rieti',
#  'sobolevo',
#  'ancud',
#  'the valley',
#  'flinders',
#  'millinocket',
#  'sayansk',
#  'nizhniy kuranakh',
#  'kautokeino',
#  'san francisco',
#  'uglovskoye',
#  'pampa',
#  'caravelas',
#  'tilichiki',
#  'shchelyayur',
#  'yumen',
#  'steinbach',
#  'gummersbach',
#  'tasbuget',
#  'porangatu',
#  'mnogovershinnyy',
#  'llanes',
#  'mago',
#  'wajima',
#  'saldanha',
#  'adrar',
#  'anadyr',
#  'kandrian',
#  'presidencia roque saenz pena',
#  'jawhar',
#  'redlands',
#  'ramshir',
#  'nechi',
#  'lafiagi',
#  'havelock',
#  'moindou',
#  'lubyany',
#  'alta floresta',
#  'mandalgovi',
#  'karasburg',
#  'pitkyaranta',
#  'oyama',
#  'alappuzha',
#  'paka',
#  'agirish',
#  'meadow lake',
#  'nouadhibou',
#  'sirjan',
#  'port blair',
#  'jutai',
#  'ginda',
#  'aswan',
#  'wad rawah',
#  'olafsvik',
#  'vysokogornyy',
#  'mayo',
#  'kenora',
#  'krasnoselkup',
#  'tehachapi',
#  'de land',
#  'flin flon',
#  'buchanan',
#  'alyangula',
#  'kekri',
#  'devils lake',
#  'bull savanna',
#  'sitio novo do tocantins',
#  'lashma',
#  'umm durman',
#  'teguise',
#  'lulea',
#  'dromolaxia',
#  'tervuren',
#  'mount isa',
#  'turan',
#  'huarmey',
#  'hasaki',
#  'acapulco',
#  'bria',
#  'dunedin',
#  'port keats',
#  'rio gallegos',
#  'alexandria',
#  'tuscaloosa',
#  'kattivakkam',
#  'kiunga',
#  'san miguel',
#  'tessalit',
#  'yenagoa',
#  'samandag',
#  'chapais',
#  'talnakh',
#  'constitucion']

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="
count = 1

lat = []
lon = []
m_temp = []
hum = []
cloud = []
wind = []
country = []
date = []

for x in cities:
    response = requests.get(url + weather_api_key + "&q=" + x).json()
    
    try:
        lat.append(response['coord']['lat'])
        lon.append(response['coord']['lon'])
        m_temp.append(response['main']['temp_max'])
        hum.append(response['main']['humidity'])
        cloud.append(response['clouds']['all'])
        wind.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
        print("Processing record", count ,"|", x)
        count = count + 1
    except KeyError:
        lat.append("")
        lon.append("")
        m_temp.append("")
        hum.append("")
        cloud.append("")
        wind.append("")
        country.append("")
        date.append("")
        print("Processing record", count ,"|", x, " |City not found")
        count = count + 1
        pass
# Out:
# Processing record 1 | castro
# Processing record 2 | bambous virieux
# Processing record 3 | port elizabeth
# Processing record 4 | severo-kurilsk
# Processing record 5 | rikitea
# Processing record 6 | barentsburg  |City not found
# Processing record 7 | palabuhanratu  |City not found
# Processing record 8 | vaini
# Processing record 9 | itoman
# Processing record 10 | dikson
# Processing record 11 | sentyabrskiy  |City not found
# Processing record 12 | tiksi
# Processing record 13 | mataura
# Processing record 14 | punta arenas
# Processing record 15 | tiznit
# Processing record 16 | busselton
# Processing record 17 | boditi
# Processing record 18 | carnarvon
# Processing record 19 | lisakovsk
# Processing record 20 | peniche
# Processing record 21 | albany
# Processing record 22 | tabiauea  |City not found
# Processing record 23 | bambanglipuro
# Processing record 24 | klaksvik
# Processing record 25 | sucre
# Processing record 26 | ambatondrazaka
# Processing record 27 | thunder bay
# Processing record 28 | mahebourg
# Processing record 29 | lebu
# Processing record 30 | bredasdorp
# Processing record 31 | puerto ayora
# Processing record 32 | clyde river
# Processing record 33 | qaanaaq
# Processing record 34 | marzuq
# Processing record 35 | ushuaia
# Processing record 36 | el real de santa maria
# Processing record 37 | saleaula  |City not found
# Processing record 38 | kapaa
# Processing record 39 | charters towers
# Processing record 40 | umzimvubu  |City not found
# Processing record 41 | grand river south east  |City not found
# Processing record 42 | codrington
# Processing record 43 | nizhneyansk  |City not found
# Processing record 44 | cairns
# Processing record 45 | bantou
# Processing record 46 | touros
# Processing record 47 | kodar
# Processing record 48 | coquimbo
# Processing record 49 | verkhnevilyuysk
# Processing record 50 | upernavik
# Processing record 51 | lasa
# Processing record 52 | jamestown
# Processing record 53 | ostrovnoy
# Processing record 54 | luderitz
# Processing record 55 | atuona
# Processing record 56 | komsomolskiy
# Processing record 57 | cabo san lucas
# Processing record 58 | hobart
# Processing record 59 | tasiilaq
# Processing record 60 | kruisfontein
# Processing record 61 | malayal
# Processing record 62 | bluff
# Processing record 63 | teya
# Processing record 64 | kaitangata
# Processing record 65 | vila velha
# Processing record 66 | norman wells
# Processing record 67 | tabou
# Processing record 68 | san juan del sur
# Processing record 69 | cogealac
# Processing record 70 | raudeberg
# Processing record 71 | mikuni
# Processing record 72 | puerto baquerizo moreno
# Processing record 73 | pevek
# Processing record 74 | kodiak
# Processing record 75 | cidreira
# Processing record 76 | ponta do sol
# Processing record 77 | butaritari
# Processing record 78 | amderma  |City not found
# Processing record 79 | mount gambier
# Processing record 80 | attawapiskat  |City not found
# Processing record 81 | bryan
# Processing record 82 | avarua
# Processing record 83 | cacador
# Processing record 84 | kosh-agach
# Processing record 85 | karkaralinsk  |City not found
# Processing record 86 | mareeba
# Processing record 87 | waingapu
# Processing record 88 | saskylakh
# Processing record 89 | laguna
# Processing record 90 | mar del plata
# Processing record 91 | pozo colorado
# Processing record 92 | provideniya
# Processing record 93 | yellowknife
# Processing record 94 | roma
# Processing record 95 | ilulissat
# Processing record 96 | taganak
# Processing record 97 | hithadhoo
# Processing record 98 | onalaska
# Processing record 99 | grindavik
# Processing record 100 | salalah
# Processing record 101 | ruatoria  |City not found
# Processing record 102 | yeppoon
# Processing record 103 | chokurdakh
# Processing record 104 | georgetown
# Processing record 105 | plouzane
# Processing record 106 | chuy
# Processing record 107 | regente feijo
# Processing record 108 | tsihombe  |City not found
# Processing record 109 | bentiu
# Processing record 110 | young
# Processing record 111 | tumannyy  |City not found
# Processing record 112 | sitka
# Processing record 113 | los llanos de aridane
# Processing record 114 | port hardy
# Processing record 115 | thompson
# Processing record 116 | mustasaari
# Processing record 117 | kirakira
# Processing record 118 | gurgan  |City not found
# Processing record 119 | nikolskoye
# Processing record 120 | ribeira grande
# Processing record 121 | arraial do cabo
# Processing record 122 | brigantine
# Processing record 123 | leghorn  |City not found
# Processing record 124 | shelburne
# Processing record 125 | barrow
# Processing record 126 | pangnirtung
# Processing record 127 | sisimiut
# Processing record 128 | victoria
# Processing record 129 | hermanus
# Processing record 130 | taolanaro  |City not found
# Processing record 131 | neryungri
# Processing record 132 | nanortalik
# Processing record 133 | pacifica
# Processing record 134 | yulara
# Processing record 135 | isangel
# Processing record 136 | hay river
# Processing record 137 | belushya guba  |City not found
# Processing record 138 | lufilufi
# Processing record 139 | new norfolk
# Processing record 140 | itaituba
# Processing record 141 | richards bay
# Processing record 142 | tornio
# Processing record 143 | sidi ali
# Processing record 144 | tautira
# Processing record 145 | fort nelson
# Processing record 146 | kuche  |City not found
# Processing record 147 | kushiro
# Processing record 148 | loukhi
# Processing record 149 | ahipara
# Processing record 150 | bastrop
# Processing record 151 | kavaratti
# Processing record 152 | urengoy
# Processing record 153 | el sauzal
# Processing record 154 | arlit
# Processing record 155 | skjervoy
# Processing record 156 | kloulklubed
# Processing record 157 | samarai
# Processing record 158 | havre-saint-pierre
# Processing record 159 | faanui
# Processing record 160 | hilo
# Processing record 161 | vaitupu  |City not found
# Processing record 162 | haines junction
# Processing record 163 | tuktoyaktuk
# Processing record 164 | benguela
# Processing record 165 | ratholo
# Processing record 166 | sioux lookout
# Processing record 167 | tazovskiy
# Processing record 168 | padang
# Processing record 169 | sampit
# Processing record 170 | krasnyy yar
# Processing record 171 | bethel
# Processing record 172 | kidal
# Processing record 173 | colac
# Processing record 174 | jumla
# Processing record 175 | khatanga
# Processing record 176 | uray
# Processing record 177 | neuquen
# Processing record 178 | cape town
# Processing record 179 | fortuna
# Processing record 180 | san quintin
# Processing record 181 | banihal
# Processing record 182 | muros
# Processing record 183 | tiarei
# Processing record 184 | seymchan
# Processing record 185 | bakchar
# Processing record 186 | ucluelet
# Processing record 187 | nadym
# Processing record 188 | san carlos de bariloche
# Processing record 189 | abnub
# Processing record 190 | namibe
# Processing record 191 | maloshuyka  |City not found
# Processing record 192 | esperance
# Processing record 193 | muroto
# Processing record 194 | celestun
# Processing record 195 | litovko
# Processing record 196 | boa vista
# Processing record 197 | avera
# Processing record 198 | comodoro rivadavia
# Processing record 199 | ouesso
# Processing record 200 | yinchuan
# Processing record 201 | broome
# Processing record 202 | lompoc
# Processing record 203 | dharchula
# Processing record 204 | beian
# Processing record 205 | belaya gora
# Processing record 206 | gravdal
# Processing record 207 | pilar
# Processing record 208 | kenai
# Processing record 209 | pimenta bueno
# Processing record 210 | firovo
# Processing record 211 | abu samrah
# Processing record 212 | la reforma
# Processing record 213 | portland
# Processing record 214 | saint-augustin
# Processing record 215 | balfour
# Processing record 216 | port-cartier
# Processing record 217 | guerrero negro
# Processing record 218 | souillac
# Processing record 219 | leningradskiy
# Processing record 220 | acarau
# Processing record 221 | oyem
# Processing record 222 | gainesville
# Processing record 223 | hamilton
# Processing record 224 | gamba
# Processing record 225 | illoqqortoormiut  |City not found
# Processing record 226 | yerbogachen
# Processing record 227 | kaeo
# Processing record 228 | rawson
# Processing record 229 | airai
# Processing record 230 | omsukchan
# Processing record 231 | ulladulla
# Processing record 232 | mirnyy
# Processing record 233 | gejiu
# Processing record 234 | kilimatinde
# Processing record 235 | pokrovsk
# Processing record 236 | bubaque
# Processing record 237 | karratha
# Processing record 238 | samusu  |City not found
# Processing record 239 | mana
# Processing record 240 | nazarovo
# Processing record 241 | nyrob
# Processing record 242 | farah
# Processing record 243 | jalu
# Processing record 244 | jalingo
# Processing record 245 | itanhandu
# Processing record 246 | kalmunai
# Processing record 247 | araguari
# Processing record 248 | port alfred
# Processing record 249 | east london
# Processing record 250 | saint anthony
# Processing record 251 | kavieng
# Processing record 252 | soyo
# Processing record 253 | samalaeulu  |City not found
# Processing record 254 | kanpur
# Processing record 255 | faya
# Processing record 256 | barcelona
# Processing record 257 | batangafo
# Processing record 258 | bandarbeyla
# Processing record 259 | talakan
# Processing record 260 | saint-paul
# Processing record 261 | kedrovyy
# Processing record 262 | lemesos  |City not found
# Processing record 263 | monrovia
# Processing record 264 | nioro
# Processing record 265 | moron
# Processing record 266 | sokode
# Processing record 267 | khuzdar
# Processing record 268 | solsvik  |City not found
# Processing record 269 | tarakan
# Processing record 270 | kamenskoye  |City not found
# Processing record 271 | petropavlovsk-kamchatskiy
# Processing record 272 | ust-kuyga
# Processing record 273 | urdzhar  |City not found
# Processing record 274 | lorengau
# Processing record 275 | manzil jamil  |City not found
# Processing record 276 | iqaluit
# Processing record 277 | mrirt  |City not found
# Processing record 278 | shahr-e kord
# Processing record 279 | katsuura
# Processing record 280 | san ramon
# Processing record 281 | mandiana
# Processing record 282 | la tuque
# Processing record 283 | veinticinco de mayo
# Processing record 284 | hambantota
# Processing record 285 | riyadh
# Processing record 286 | vao
# Processing record 287 | chumikan
# Processing record 288 | lano
# Processing record 289 | carballo
# Processing record 290 | sorland
# Processing record 291 | mys shmidta  |City not found
# Processing record 292 | kropotkin
# Processing record 293 | vestmannaeyjar
# Processing record 294 | kaupanger
# Processing record 295 | prince rupert
# Processing record 296 | zyryanka
# Processing record 297 | taua
# Processing record 298 | coihaique
# Processing record 299 | phan thiet
# Processing record 300 | doha
# Processing record 301 | kiruna
# Processing record 302 | nishihara
# Processing record 303 | cascais
# Processing record 304 | yaan
# Processing record 305 | maumere
# Processing record 306 | torbay
# Processing record 307 | saint-philippe
# Processing record 308 | george
# Processing record 309 | kashi
# Processing record 310 | buritis
# Processing record 311 | koumac
# Processing record 312 | chikoy  |City not found
# Processing record 313 | saint-joseph
# Processing record 314 | taman
# Processing record 315 | viligili  |City not found
# Processing record 316 | ust-nera
# Processing record 317 | bairnsdale
# Processing record 318 | moose factory
# Processing record 319 | tucuman
# Processing record 320 | longhua
# Processing record 321 | la rioja
# Processing record 322 | gasa
# Processing record 323 | montepuez
# Processing record 324 | kracheh  |City not found
# Processing record 325 | khorinsk
# Processing record 326 | hualmay
# Processing record 327 | lavrentiya
# Processing record 328 | bosaso
# Processing record 329 | banjar
# Processing record 330 | xuddur
# Processing record 331 | anshun
# Processing record 332 | ustka
# Processing record 333 | darhan
# Processing record 334 | salinopolis
# Processing record 335 | salekhard
# Processing record 336 | beloha
# Processing record 337 | simao
# Processing record 338 | boromo
# Processing record 339 | akropong
# Processing record 340 | ossora
# Processing record 341 | carutapera
# Processing record 342 | tshikapa
# Processing record 343 | chifeng
# Processing record 344 | bilibino
# Processing record 345 | narsaq
# Processing record 346 | morondava
# Processing record 347 | san vicente
# Processing record 348 | bobon
# Processing record 349 | milledgeville
# Processing record 350 | baker city
# Processing record 351 | lagoa
# Processing record 352 | san patricio
# Processing record 353 | praia da vitoria
# Processing record 354 | hun
# Processing record 355 | vostok
# Processing record 356 | goderich
# Processing record 357 | dzhebariki-khaya
# Processing record 358 | ubinskoye
# Processing record 359 | cockburn town
# Processing record 360 | buala
# Processing record 361 | cuiaba
# Processing record 362 | kitui
# Processing record 363 | kibuye
# Processing record 364 | vila franca do campo
# Processing record 365 | cap-aux-meules
# Processing record 366 | marcona  |City not found
# Processing record 367 | saint-francois
# Processing record 368 | pilao arcado  |City not found
# Processing record 369 | sumbe
# Processing record 370 | zirgan
# Processing record 371 | anloga
# Processing record 372 | yamada
# Processing record 373 | shiraz
# Processing record 374 | galiwinku  |City not found
# Processing record 375 | luwuk
# Processing record 376 | sandpoint
# Processing record 377 | coxim
# Processing record 378 | bathsheba
# Processing record 379 | beyneu
# Processing record 380 | abrau-dyurso
# Processing record 381 | tutoia
# Processing record 382 | formiga
# Processing record 383 | lima
# Processing record 384 | wattegama
# Processing record 385 | kinkala
# Processing record 386 | corrente
# Processing record 387 | suez
# Processing record 388 | macheng
# Processing record 389 | aksarka
# Processing record 390 | lasem
# Processing record 391 | outjo
# Processing record 392 | egvekinot
# Processing record 393 | fukuma
# Processing record 394 | tres palos
# Processing record 395 | romny
# Processing record 396 | formosa
# Processing record 397 | nome
# Processing record 398 | lolua  |City not found
# Processing record 399 | maxixe
# Processing record 400 | ville-marie
# Processing record 401 | piracicaba
# Processing record 402 | tuatapere
# Processing record 403 | araouane
# Processing record 404 | kesennuma  |City not found
# Processing record 405 | tlapacoyan
# Processing record 406 | kahului
# Processing record 407 | cisarua
# Processing record 408 | khorixas
# Processing record 409 | broken hill
# Processing record 410 | dingle
# Processing record 411 | camacha
# Processing record 412 | visby
# Processing record 413 | dwarka
# Processing record 414 | fairbanks
# Processing record 415 | fare
# Processing record 416 | okha
# Processing record 417 | manado
# Processing record 418 | trinidad
# Processing record 419 | cuencame
# Processing record 420 | stony plain
# Processing record 421 | gorontalo
# Processing record 422 | sakakah
# Processing record 423 | saint-georges
# Processing record 424 | tumpat
# Processing record 425 | kupang
# Processing record 426 | namatanai
# Processing record 427 | manthani
# Processing record 428 | itarema
# Processing record 429 | borba
# Processing record 430 | saint george
# Processing record 431 | gemlik
# Processing record 432 | sambava
# Processing record 433 | hunza  |City not found
# Processing record 434 | amuntai
# Processing record 435 | machala
# Processing record 436 | kapuskasing
# Processing record 437 | sesheke
# Processing record 438 | erzin
# Processing record 439 | sao filipe
# Processing record 440 | loiza
# Processing record 441 | west plains
# Processing record 442 | hornepayne
# Processing record 443 | hays
# Processing record 444 | bargal  |City not found
# Processing record 445 | amahai
# Processing record 446 | bulgan
# Processing record 447 | hovd
# Processing record 448 | dzhusaly  |City not found
# Processing record 449 | arona
# Processing record 450 | tudela
# Processing record 451 | dalvik
# Processing record 452 | alofi
# Processing record 453 | louisbourg  |City not found
# Processing record 454 | zwedru
# Processing record 455 | loandjili
# Processing record 456 | hagersville
# Processing record 457 | bacuit  |City not found
# Processing record 458 | mitsamiouli
# Processing record 459 | gaspe
# Processing record 460 | lamu
# Processing record 461 | atambua
# Processing record 462 | burica  |City not found
# Processing record 463 | berlevag
# Processing record 464 | dianopolis  |City not found
# Processing record 465 | surt
# Processing record 466 | pacific grove
# Processing record 467 | yamethin
# Processing record 468 | cherskiy
# Processing record 469 | sonoita
# Processing record 470 | cap malheureux
# Processing record 471 | taungdwingyi
# Processing record 472 | longyearbyen
# Processing record 473 | da nang
# Processing record 474 | palmer
# Processing record 475 | abu kamal
# Processing record 476 | hollabrunn
# Processing record 477 | sorvag  |City not found
# Processing record 478 | san jeronimo
# Processing record 479 | chivay
# Processing record 480 | soloneshnoye
# Processing record 481 | davila
# Processing record 482 | fomboni
# Processing record 483 | geraldton
# Processing record 484 | tura
# Processing record 485 | kosa
# Processing record 486 | fereydun kenar
# Processing record 487 | hihifo  |City not found
# Processing record 488 | aneho
# Processing record 489 | gushikawa
# Processing record 490 | san francisco de macoris
# Processing record 491 | senanga
# Processing record 492 | darnah
# Processing record 493 | verkhoyansk
# Processing record 494 | aklavik
# Processing record 495 | wamba
# Processing record 496 | palauig
# Processing record 497 | matagami
# Processing record 498 | zelenets
# Processing record 499 | mozarlandia
# Processing record 500 | felipe carrillo puerto
# Processing record 501 | concordia
# Processing record 502 | maryborough
# Processing record 503 | buin
# Processing record 504 | ust-kamchatsk  |City not found
# Processing record 505 | solnechnyy
# Processing record 506 | westport
# Processing record 507 | marrakesh
# Processing record 508 | naryan-mar
# Processing record 509 | ust-kulom
# Processing record 510 | batagay
# Processing record 511 | barabinsk
# Processing record 512 | mamlyutka
# Processing record 513 | kangar
# Processing record 514 | jinchang
# Processing record 515 | yaitepec  |City not found
# Processing record 516 | hirara
# Processing record 517 | abu road
# Processing record 518 | bengkulu
# Processing record 519 | saint-pierre
# Processing record 520 | lata
# Processing record 521 | inhambane
# Processing record 522 | luanda
# Processing record 523 | satitoa  |City not found
# Processing record 524 | honningsvag
# Processing record 525 | sira
# Processing record 526 | general roca
# Processing record 527 | petrykiv
# Processing record 528 | harper
# Processing record 529 | rieti
# Processing record 530 | sobolevo
# Processing record 531 | ancud
# Processing record 532 | the valley
# Processing record 533 | flinders
# Processing record 534 | millinocket
# Processing record 535 | sayansk
# Processing record 536 | nizhniy kuranakh
# Processing record 537 | kautokeino
# Processing record 538 | san francisco
# Processing record 539 | uglovskoye
# Processing record 540 | pampa
# Processing record 541 | caravelas
# Processing record 542 | tilichiki
# Processing record 543 | shchelyayur  |City not found
# Processing record 544 | yumen
# Processing record 545 | steinbach
# Processing record 546 | gummersbach
# Processing record 547 | tasbuget  |City not found
# Processing record 548 | porangatu
# Processing record 549 | mnogovershinnyy
# Processing record 550 | llanes
# Processing record 551 | mago
# Processing record 552 | wajima
# Processing record 553 | saldanha
# Processing record 554 | adrar
# Processing record 555 | anadyr
# Processing record 556 | kandrian
# Processing record 557 | presidencia roque saenz pena
# Processing record 558 | jawhar
# Processing record 559 | redlands
# Processing record 560 | ramshir
# Processing record 561 | nechi
# Processing record 562 | lafiagi
# Processing record 563 | havelock
# Processing record 564 | moindou
# Processing record 565 | lubyany
# Processing record 566 | alta floresta
# Processing record 567 | mandalgovi
# Processing record 568 | karasburg
# Processing record 569 | pitkyaranta
# Processing record 570 | oyama
# Processing record 571 | alappuzha
# Processing record 572 | paka
# Processing record 573 | agirish
# Processing record 574 | meadow lake
# Processing record 575 | nouadhibou
# Processing record 576 | sirjan
# Processing record 577 | port blair
# Processing record 578 | jutai
# Processing record 579 | ginda
# Processing record 580 | aswan
# Processing record 581 | wad rawah
# Processing record 582 | olafsvik
# Processing record 583 | vysokogornyy
# Processing record 584 | mayo
# Processing record 585 | kenora
# Processing record 586 | krasnoselkup
# Processing record 587 | tehachapi
# Processing record 588 | de land
# Processing record 589 | flin flon
# Processing record 590 | buchanan
# Processing record 591 | alyangula
# Processing record 592 | kekri
# Processing record 593 | devils lake
# Processing record 594 | bull savanna
# Processing record 595 | sitio novo do tocantins
# Processing record 596 | lashma
# Processing record 597 | umm durman  |City not found
# Processing record 598 | teguise
# Processing record 599 | lulea
# Processing record 600 | dromolaxia
# Processing record 601 | tervuren
# Processing record 602 | mount isa
# Processing record 603 | turan
# Processing record 604 | huarmey
# Processing record 605 | hasaki
# Processing record 606 | acapulco
# Processing record 607 | bria
# Processing record 608 | dunedin
# Processing record 609 | port keats
# Processing record 610 | rio gallegos
# Processing record 611 | alexandria
# Processing record 612 | tuscaloosa
# Processing record 613 | kattivakkam
# Processing record 614 | kiunga
# Processing record 615 | san miguel
# Processing record 616 | tessalit
# Processing record 617 | yenagoa
# Processing record 618 | samandag
# Processing record 619 | chapais
# Processing record 620 | talnakh
# Processing record 621 | constitucion

# %%
weather_df = pd.DataFrame({"Cities" : cities, "Lat" : lat, "Lng" : lon, "Max Temp" : m_temp, "Humidity" : hum, "Cloudiness" : cloud, 
                           "Wind Speed" : wind, "Country" : country, "Date" : date})
weather_df.replace('', np.nan, inplace=True)
weather_df.dropna(inplace=True)
weather_df
# Out:
#               Cities    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0             castro -24.79  -50.01     60.80      77.0         4.0
# 1    bambous virieux -20.34   57.76     71.60      78.0        40.0
# 2     port elizabeth -33.92   25.57     46.40      81.0         0.0
# 3     severo-kurilsk  50.68  156.12     49.78      92.0       100.0
# 4            rikitea -23.12 -134.97     71.11      72.0         0.0
# ..               ...    ...     ...       ...       ...         ...
# 616          yenagoa   4.92    6.26     74.41      94.0        95.0
# 617         samandag  36.08   35.98     80.60      74.0        20.0
# 618          chapais  49.78  -74.85     62.60      88.0        90.0
# 619          talnakh  69.49   88.40     53.60      81.0        75.0
# 620     constitucion -35.33  -72.42     53.67      81.0       100.0
#
#      Wind Speed Country          Date
# 0          7.31      BR  1.594591e+09
# 1         13.87      MU  1.594591e+09
# 2          1.12      ZA  1.594591e+09
# 3          8.46      RU  1.594591e+09
# 4         16.62      PF  1.594591e+09
# ..          ...     ...           ...
# 616        3.47      NG  1.594591e+09
# 617       14.99      TR  1.594591e+09
# 618       10.29      CA  1.594591e+09
# 619        4.47      RU  1.594591e+09
# 620        6.60      CL  1.594591e+09
#
# [567 rows x 9 columns]

# %%
weather_df["Humidity"].max()
# Out:
# 100.0

# %%
weather_df.to_csv("output_data/cities.csv", index=False)

# %%
max_temp_y = weather_df["Max Temp"]
lat_x = weather_df["Lat"]
plt.scatter(lat_x, max_temp_y, edgecolors="black")
plt.grid()

plt.title("City Latitude vs Max Temperature (7/12/20)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.savefig("output_data/scatter_lat_temp.png")

#chart indicating a curvilinear relationship between Max Temp and Latitude 
#with lower temps recorded further away from 0 latitude and higher temps in the 10-40 latitude range.

# %%
humidity_y = weather_df["Humidity"]
lat_x = weather_df["Lat"]
plt.scatter(lat_x, humidity_y, edgecolors="black")
plt.grid()

plt.title("City Latitude vs Humidity (7/12/20)")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("output_data/scatter_lat_hum.png")

#chart indicating the relationship between Humidity and Latitude.  
#It appears that there is not a strong correlation between these variables

# %%
cloud_y = weather_df["Cloudiness"]
lat_x = weather_df["Lat"]
plt.scatter(lat_x, cloud_y, edgecolors="black")
plt.grid()

plt.title("City Latitude vs Cloudiness (7/12/20)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("output_data/scatter_lat_cloud.png")

#chart indicating the relationship between Cloudiness and Latitude.  
#It appears that there is not a strong correlation between these variables

# %%
wind_y = weather_df["Wind Speed"]
lat_x = weather_df["Lat"]
plt.scatter(lat_x, wind_y, edgecolors="black")
plt.grid()

plt.title("City Latitude vs Wind Speed (7/12/20)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("output_data/scatter_lat_wind.png")

#chart indicating the relationship between Cloudiness and Wind Speed.  
#It appears that there is not a strong correlation between these variables

# %%
weather_nh = weather_df[weather_df.Lat > 0]
weather_sh = weather_df[weather_df.Lat < 0]
weather_nh
# Out:
#              Cities    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 3    severo-kurilsk  50.68  156.12     49.78      92.0       100.0
# 8            itoman  26.12  127.67     84.20      83.0        75.0
# 9            dikson  73.51   80.55     42.13      97.0        99.0
# 11            tiksi  71.69  128.87     61.29      69.0       100.0
# 14           tiznit  29.58   -9.50     83.05      36.0        82.0
# ..              ...    ...     ...       ...       ...         ...
# 615        tessalit  20.20    1.01     94.15      25.0        43.0
# 616         yenagoa   4.92    6.26     74.41      94.0        95.0
# 617        samandag  36.08   35.98     80.60      74.0        20.0
# 618         chapais  49.78  -74.85     62.60      88.0        90.0
# 619         talnakh  69.49   88.40     53.60      81.0        75.0
#
#      Wind Speed Country          Date
# 3          8.46      RU  1.594591e+09
# 8          3.36      JP  1.594591e+09
# 9          6.55      RU  1.594591e+09
# 11         5.88      RU  1.594591e+09
# 14         0.72      MA  1.594591e+09
# ..          ...     ...           ...
# 615       10.94      ML  1.594591e+09
# 616        3.47      NG  1.594591e+09
# 617       14.99      TR  1.594591e+09
# 618       10.29      CA  1.594591e+09
# 619        4.47      RU  1.594591e+09
#
# [385 rows x 9 columns]

# %%
from scipy.stats import linregress

(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_nh["Lat"], weather_nh["Max Temp"])
regress_values = weather_nh["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(weather_nh["Lat"], weather_nh["Max Temp"])
plt.plot(weather_nh["Lat"],regress_values,"r-")
plt.annotate(line_eq,(18,36),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temerature (F)')    
plt.title("Northern Hemisphere - Max Temp vs. Latitude Linear Regression (7/12/20)")
print("R value = ", round(rvalue, 2))
print("R squared = ", round(rvalue*rvalue, 2))
print("p value =", pvalue, ", significant at the alpha of .05")
plt.savefig("output_data/regnh_lat_temp.png")

#there is a significant negative correlation between latitude and Max Temperature in the Northern Hemisphere, 
#where that 44% of the variability seen in Max Temperature can be attributed to the Latitude variable.
# Out:
# R value =  -0.66
# R squared =  0.44
# p value = 1.604421664713819e-49 , significant at the alpha of .05

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_sh["Lat"], weather_sh["Max Temp"])
regress_values = weather_sh["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(weather_sh["Lat"], weather_sh["Max Temp"])
plt.plot(weather_sh["Lat"],regress_values,"r-")
plt.annotate(line_eq,(18,36),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temerature (F)')    
plt.title("Southern Hemisphere - Max Temp vs. Latitude Linear Regression (7/12/20)")
print("R value = ", round(rvalue,2))
print("Rsquared = ", round(rvalue*rvalue,2))
print("p value =", pvalue, ", significant at the alpha of .05")
plt.savefig("output_data/regsh_lat_temp.png")

#there is a significant positive correlation between latitude and Max Temperature in the Southern Hemisphere, 
#where that 65% of the variability seen in Max Temperature can be attributed to the Latitude variable.
# Out:
# R value =  0.81
# Rsquared =  0.65
# p value = 3.7558596192763524e-43 , significant at the alpha of .05

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_nh["Lat"], weather_nh["Humidity"])
regress_values = weather_nh["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(weather_nh["Lat"], weather_nh["Humidity"])
plt.plot(weather_nh["Lat"],regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')    
plt.title("Northern Hemisphere - Humidity vs. Latitude Linear Regression (7/12/20)")
print("R value = ", round(rvalue, 2))
print("R squared = ", round(rvalue*rvalue, 2))
print("p value =", pvalue, ", not significant at the alpha of .05")
plt.savefig("output_data/regnh_lat_hum.png")

#there is no significant correlation between latitude and Humidity in the Northern Hemisphere,
# Out:
# R value =  -0.02
# R squared =  0.0
# p value = 0.6760961358307735 , not significant at the alpha of .05

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_sh["Lat"], weather_sh["Humidity"])
regress_values = weather_sh["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(weather_sh["Lat"], weather_sh["Humidity"])
plt.plot(weather_sh["Lat"],regress_values,"r-")
plt.annotate(line_eq,(50,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')    
plt.title("Southern Hemisphere - Humidity vs. Latitude Linear Regression (7/12/20)")
print("R value = ", round(rvalue, 2))
print("R squared = ", round(rvalue*rvalue, 2))
print("p value =", pvalue, ", not significant at the alpha of .05")
plt.savefig("output_data/regsh_lat_hum.png")

#there is no significant correlation between latitude and Humidity in the Southern Hemisphere,
# Out:
# R value =  0.14
# R squared =  0.02
# p value = 0.0674408447308329 , not significant at the alpha of .05

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_nh["Lat"], weather_nh["Cloudiness"])
regress_values = weather_nh["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(weather_nh["Lat"], weather_nh["Cloudiness"])
plt.plot(weather_nh["Lat"],regress_values,"r-")
plt.annotate(line_eq,(54,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')    
plt.title("Northern Hemisphere - Cloudiness vs. Latitude Linear Regression (7/12/20)")
print("R value = ", round(rvalue, 2))
print("R squared = ", round(rvalue*rvalue, 2))
print("p value =", pvalue, ", not significant at the alpha of .05")
plt.savefig("output_data/regnh_lat_cloud.png")

#there is no significant correlation between latitude and Cloudiness in the Northern Hemisphere,
# Out:
# R value =  0.05
# R squared =  0.0
# p value = 0.3623855768866766 , not significant at the alpha of .05

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_sh["Lat"], weather_sh["Cloudiness"])
regress_values = weather_sh["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(weather_sh["Lat"], weather_sh["Cloudiness"])
plt.plot(weather_sh["Lat"],regress_values,"r-")
plt.annotate(line_eq,(54,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')    
plt.title("Southern Hemisphere - Cloudiness vs. Latitude Linear Regression (7/12/20)")
print("R value = ", round(rvalue, 2))
print("R squared = ", round(rvalue*rvalue, 2))
print("p value =", pvalue, ", not significant at the alpha of .05")
plt.savefig("output_data/regsh_lat_cloud.png")

#there is no significant correlation between latitude and Cloudiness in the Southern Hemisphere,
# Out:
# R value =  0.13
# R squared =  0.02
# p value = 0.08679929125991782 , not significant at the alpha of .05

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_nh["Lat"], weather_nh["Wind Speed"])
regress_values = weather_nh["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(weather_nh["Lat"], weather_nh["Wind Speed"])
plt.plot(weather_nh["Lat"],regress_values,"r-")
plt.annotate(line_eq,(20,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')    
plt.title("Northern Hemisphere - Wind Speed vs. Latitude Linear Regression (7/12/20)")
print("R value = ", round(rvalue, 2))
print("R squared = ", round(rvalue*rvalue, 2))
print("p value =", pvalue, ", not significant at the alpha of .05")
plt.savefig("output_data/regnh_lat_wind.png")

#there is no significant correlation between latitude and Wind Speed in the Northern Hemisphere,
# Out:
# R value =  -0.09
# R squared =  0.01
# p value = 0.08885276721028357 , not significant at the alpha of .05

# %%
(slope, intercept, rvalue, pvalue, stderr) = linregress(weather_sh["Lat"], weather_sh["Wind Speed"])
regress_values = weather_sh["Lat"] * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(weather_sh["Lat"], weather_sh["Wind Speed"])
plt.plot(weather_sh["Lat"],regress_values,"r-")
plt.annotate(line_eq,(-30,25),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')    
plt.title("Southern Hemisphere - Wind Speed vs. Latitude Linear Regression (7/12/20)")
print("R value = ", round(rvalue, 2))
print("R squared = ", round(rvalue*rvalue, 2))
print("p value =", pvalue, ", significant at the alpha of .05")
plt.savefig("output_data/regsh_lat_wind.png")

#there is a significant negative correlation between latitude and Wind Speed in the Southern Hemisphere,
#where 4% of the variability in Wind Speed can be attributed to Latitude.
# Out:
# R value =  -0.19
# R squared =  0.04
# p value = 0.008941276814822607 , significant at the alpha of .05

# %%
# Final Observations:

# 1. There is a significant correlation between latitude and Max Temp as run on July 12, 2020.
#    so that the further away from the equator, the warmer the max temperature
#    The effect size is stronger in the southern hemisphere (r2 = .65), than in the northern (r2 = .44)

# 2. Latitude is not a significant preditor of Humidity, Cloudiness, or Wind Speed

# 3. It would be interesting to run the same numbers or these variables in the Winter to see if time of year impacts
#    the strength of the relationships between the variables.
